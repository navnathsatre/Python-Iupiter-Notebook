# %%
from bs4 import BeautifulSoup
import requests

# %%
# url = "https://medium.com/@nishesh.kumar/data-science-interview-questions-on-dimensional-reduction-fb8df2b239dd"
# url = "https://thinkingneuron.com/data-science-interview-questions-for-it-industry-part-4-unsupervised-ml/"
url = "https://www.analyticsvidhya.com/blog/2017/03/questions-dimensionality-reduction-data-scientist/"

# %%
# access result through requests object
result = requests.get(url)
# load teh page content
page_content = result.content
# create soup object
soup = BeautifulSoup(page_content, "html.parser")

# %%
# view the content
soup.contents
# Out:
# ['html',
#  '\n',
#  <html lang="en">
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#  <meta content="telephone=no" name="format-detection"/>
#  <meta content="address=no" name="format-detection"/>
#  <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" id="favicon" rel="icon" type="image/x-icon"/>
#  <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon"/>
#  <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="76x76"/>
#  <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="114x114"/>
#  <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="144x144"/>
# ...

# %%
# prettify (to generate output)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="address=no" name="format-detection"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" id="favicon" rel="icon" type="image/x-icon"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="144x144"/>
# ...

# %%
# view the original encoding
soup.original_encoding
# Out:
# 'utf-8'

# %%
# format the tag a to xml
# soup.body.a.prettify(formatter="xml")

# %%
soup.get_text()
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n40 Must know Questions to test a data scientist on Dimensionality Reduction techniques\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nsearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nStart Here\n\n\n\n\nMachine Learning\n\n\nDeep Learning\n\n\nNLP\n\n\n\n\n\nArticles\n\n\n\nMachine Learning\n\n\nDeep Learning\n\n\nNLP\n\n\nComputer Vision\n\n\nData Visualization\n\n\nCareers\n\n\nMore\n\nInfographics\nJobs\nPodcasts\nE-Books\nFor Companies\nDatahack Summit\nDSAT\nGlossary\nArchive\n\n\n Write an Article\n\n\n\n\nCourses\n\n\n\nCertified AI & ML BlackBelt Plus\n\n\nAscend Pro\n\n\nData Science Immersive Bootcamp\n\n All Courses\n\n\n\n\nJob-A-Thon\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSign in\n\n\nJoin Now\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nManage your AV Account\nMy Hackathons\nMy Bookmarks\nMy Courses\nMy Applied Jobs\n\n\nSign Out\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n
# ...

# %%
soup.title
# Out:
# <title>40 Must know Questions to test a data scientist on Dimensionality Reduction techniques</title>

# %%
soup.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="address=no" name="format-detection"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" id="favicon" rel="icon" type="image/x-icon"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="114x114"/>
# <link href="https://www.analyticsvidhya.com/wp-content/uploads/2015/02/logo_square_v2.jpg" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/4.1.0/animate.min.css" rel="stylesheet">
# ...

# %%
# find all teh links present on teh web page
for href in soup.findAll('a', href=True):
    print(href['href'])
# Out:
# https://www.analyticsvidhya.com/blog/
# javascript:void(0);
# https://courses.analyticsvidhya.com/courses/Machine-Learning-Certification-Course-for-Beginners?utm_source=blog_navbar&utm_medium=start_here_button
# https://courses.analyticsvidhya.com/courses/getting-started-with-neural-networks?utm_source=blog_navbar&utm_medium=start_here_button
# https://courses.analyticsvidhya.com/courses/Intro-to-NLP?utm_source=blog_navbar&utm_medium=start_here_button
# javascript:void(0);
# https://www.analyticsvidhya.com/blog/category/machine-learning/?utm_source=blog_navbar&utm_medium=machine_learning_button
# https://www.analyticsvidhya.com/blog/category/deep-learning/?utm_source=blog_navbar&utm_medium=deep_learning_button
# https://www.analyticsvidhya.com/blog/category/nlp/?utm_source=blog_navbar&utm_medium=_button
# https://www.analyticsvidhya.com/blog/category/computer-vision/?utm_source=blog_navbar&utm_medium=article_button
# ...

# %%
for article in soup.find_all("h2"):
    print(article.string)
# Out:
# Introduction
# Overall Scores
# Useful Resources
# Questions & Answers
# None
# None
# Top Resources
# None

# %%
for article in soup.find_all("h3"):
    print(article.string)
# Out:
# End Notes
# Related
# About the Author
# Our Top Authors
# None
# None

# %%
for tag in soup.findAll(True):
    print(tag.name, end = ", ")
# Out:
# html, head, meta, meta, meta, meta, link, link, link, link, link, link, link, link, link, link, link, link, script, title, script, noscript, iframe, style, meta, meta, link, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, meta, script, link, link, script, style, link, link, link, style, link, link, link, link, link, link, script, script, script, script, script, link, link, link, link, meta, link, link, link, script, script, link, body, div, div, header, div, div, nav, a, img, div, form, div, label, div, input, div, div, i, button, i, div, ul, li, a, i, div, ul, li, a, li, a, li, a, li, a, div, ul, li, a, li, a, li, a, li, a, li, a, li, a, li, a, div, a, a, a, a, a, a, a, a, a, a, li, a, div, ul, li, a, li, a, li, a, a, li, a, div, ul, li, a, i, li, a, svg, path, li, a, li, a, li, span, em, img, div, div, div, span, em, img, h6, small, div, a, a, a, a, a, div, a, div, section, div, div, div, p, a, div, span, h4, sup, span, h4
# ...
